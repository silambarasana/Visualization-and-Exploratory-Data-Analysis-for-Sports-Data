# %% [markdown]
# ## <font color='green'>***Case Study***</font>
# - Lets consider a National Hockey League (NHL) data for exploratory data analysis.
# - It is widely accepted among NHL fans that NHL players who rack up higher numbers in categories like shots, games played, and time-on-ice are more likely to score a higher number of goals and assists in a season. This report explores these assumptions by analyzing 20 seasons of NHL statistics.
# - The data contains categories, and the population represented is every NHL player from 1999-2018.
# - The categories for analysis include a player’s position, goals, assists, points, shots, games played, time-on-ice, blocks, and hits.
# - More specifically, each category was analyzed to discover how they correlate with higher goals and assists scored in a season, and which position typically earns the most goals, assists, blocks, and hits per season.

# %% [markdown]
# ## <font color='green'>***Exploratory Data Analysis (EDA)***</font>
# - In statistics, exploratory data analysis is an approach of analyzing data sets to summarize their main characteristics, often using statistical graphics and other data visualization methods
# - It is a good practice to understand the data first and try to gather as many insights from it. EDA is all about making sense of data
# -  EDA which focuses more narrowly on checking assumptions required for model fitting and hypothesis testing, and handling missing values and making transformations of variables as needed.
# - Visualization plays a major role in performing EDA. In this project we will focus on visualization, different plots and their interpretation.
# - EDA can be performed using:
#   - Univariate Analysis
#   - Bivariate Analysis
#   - Multivariate Analysis

# %% [markdown]
# ### Import  the necessary libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
# %matplotlib inline
import plotly.express as px

# %%
df = pd.read_csv('nhl_stats.csv')
df.head(5)
# Out:
#    season            player  age   team position  games_played  goals  \
# 0    2018      Pontus Aberg   24   TOT       LW             53      4
# 1    2018      Noel Acciari   26   BOS        C             60     10
# 2    2018    Michael Amadio   21   LAK        C             37      4
# 3    2018     Andy Andreoff   26   LAK       LW             45      3
# 4    2018  Sven Andrighetto   24   COL       RW             50      8
#
#    goals_per_game  assists  points  shots  shot_percentage  time_on_ice  \
# 0          0.0755       12      16     70              6.0        645.0
# 1          0.1667        1      11     66             15.0        775.0
# 2          0.1081        4       8     28             14.0        345.0
# 3          0.0667        6       9     47              6.0        423.0
# 4          0.1600       14      22    111              7.0        724.0
#
#    blocks  hits
# 0       8    24
# 1      41   152
# 2       9    18
# 3      11    77
# 4      18    38

# %% [markdown]
# #### Getting Insights from data

# %%
df.shape
# Out:
# (5262, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5262 entries, 0 to 5261
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   season           5262 non-null   int64
#  1   player           5262 non-null   object
#  2   age              5262 non-null   int64
#  3   team             5262 non-null   object
#  4   position         5262 non-null   object
#  5   games_played     5262 non-null   int64
#  6   goals            5262 non-null   int64
#  7   goals_per_game   5262 non-null   float64
#  8   assists          5262 non-null   int64
#  9   points           5262 non-null   int64
#  10  shots            5262 non-null   int64
#  11  shot_percentage  5262 non-null   float64
#  12  time_on_ice      5262 non-null   float64
#  13  blocks           5262 non-null   int64
#  14  hits             5262 non-null   int64
# dtypes: float64(3), int64(9), object(3)
# memory usage: 616.8+ KB

# %%
df.columns
# Out:
# Index(['season', 'player', 'age', 'team', 'position', 'games_played', 'goals',
#        'goals_per_game', 'assists', 'points', 'shots', 'shot_percentage',
#        'time_on_ice', 'blocks', 'hits'],
#       dtype='object')

# %%
df.nunique()
# Out:
# season               19
# player             2028
# age                  27
# team                 35
# position              8
# games_played         57
# goals                32
# goals_per_game      648
# assists              41
# points               61
# shots               182
# shot_percentage      32
# time_on_ice         854
# blocks              114
# hits                235
# dtype: int64

# %%
df.head()
# Out:
#    season            player  age   team position  games_played  goals  \
# 0    2018      Pontus Aberg   24   TOT       LW             53      4
# 1    2018      Noel Acciari   26   BOS        C             60     10
# 2    2018    Michael Amadio   21   LAK        C             37      4
# 3    2018     Andy Andreoff   26   LAK       LW             45      3
# 4    2018  Sven Andrighetto   24   COL       RW             50      8
#
#    goals_per_game  assists  points  shots  shot_percentage  time_on_ice  \
# 0          0.0755       12      16     70              6.0        645.0
# 1          0.1667        1      11     66             15.0        775.0
# 2          0.1081        4       8     28             14.0        345.0
# 3          0.0667        6       9     47              6.0        423.0
# 4          0.1600       14      22    111              7.0        724.0
#
#    blocks  hits
# 0       8    24
# 1      41   152
# 2       9    18
# 3      11    77
# 4      18    38

# %% [markdown]
# ## <font color = 'green' > Univariate Analysis - Analysis of Single Variable

# %% [markdown]
# ### i)   Continuous Feature
# - Dist Plot
# - Histogram
# - Box Plot

# %%
sns.displot(df['games_played'])
plt.ylabel('The count for each bin')
plt.show()

# %% [markdown]
# ###  <font color = 'blue'> Inference
# - There is no clear pattern but near to normal distribution

# %%
sns.displot(df['games_played'], kde = True)
plt.show()

# %% [markdown]
# ###  <font color = 'blue'> Inference
# - This is shows as similar to above displot and also shows kernal density estimator with normal distribution but no clear pattern

# %%
sns.histplot(df['goals_per_game'])
plt.show()

# %% [markdown]
# ### <font color = 'blue'> Inference
# - Distribution is positive skewed which is tail towards right

# %%
sns.boxplot(x = df['age'])
plt.show()

# %% [markdown]
# ### <font color = 'blue'> Inference
# - Box plot helps us to find the outliers
# - The mean/median age is 26 and there are few outlier in age feature

# %%
df.nunique()
# Out:
# season               19
# player             2028
# age                  27
# team                 35
# position              8
# games_played         57
# goals                32
# goals_per_game      648
# assists              41
# points               61
# shots               182
# shot_percentage      32
# time_on_ice         854
# blocks              114
# hits                235
# dtype: int64

# %%
sns.boxplot(x = df['games_played'])
plt.show()

# %% [markdown]
# ### <font color = 'blue'> Inference
# - There are no outliers in games_played feature
# - The median value of games_played is 50

# %%
sns.boxplot(x = df['goals'])
plt.show()

# %% [markdown]
# ### <font color = 'blue'> Inference
# - The median value of goals scored is 4 and there is presence many outliers in goals feature

# %% [markdown]
# ###  Categorical and Discrete Features
# - Bar Plot
# - Count Plot
# - Pie Plot

# %%
df.columns
# Out:
# Index(['season', 'player', 'age', 'team', 'position', 'games_played', 'goals',
#        'goals_per_game', 'assists', 'points', 'shots', 'shot_percentage',
#        'time_on_ice', 'blocks', 'hits'],
#       dtype='object')

# %%
df
# Out:
#       season            player  age   team position  games_played  goals  \
# 0       2018      Pontus Aberg   24   TOT       LW             53      4
# 1       2018      Noel Acciari   26   BOS        C             60     10
# 2       2018    Michael Amadio   21   LAK        C             37      4
# 3       2018     Andy Andreoff   26   LAK       LW             45      3
# 4       2018  Sven Andrighetto   24   COL       RW             50      8
# ...      ...               ...  ...    ...      ...           ...    ...
# 5257    1999       Rene Corbet   25   TOT       LW             73     13
# 5258    1999   Sandis Ozolinsh   26   COL        D             39      7
# 5259    1999    Donald Audette   29   LAK       RW             49     18
# 5260    1999       Doug Weight   28   EDM        C             43      6
# 5261    1999    Steve Sullivan   24   TOR        C             63     20
#
#       goals_per_game  assists  points  shots  shot_percentage  time_on_ice  \
# ...

# %% [markdown]
# #### Q1.How many matches were played in 2017 ?

# %%
df['season'].value_counts()
# Out:
# 2013    492
# 2004    289
# 2001    282
# 2012    278
# 2000    276
# 2008    274
# 2006    273
# 2003    272
# 2009    268
# 2018    263
# 2015    263
# 2014    261
# 2002    260
# 2010    258
# 2017    257
# 2016    253
# 2011    251
# 2007    250
# 1999    242
# Name: season, dtype: int64

# %%
df['season'][df['season'] == 2017].value_counts() # Total 257 games played in year 2017
# Out:
# 2017    257
# Name: season, dtype: int64

# %% [markdown]
# #### Q2. In which year maximum matches were played? We can check using bar plot by pandas dataframe.

# %%
df['season'].value_counts().plot.bar()
plt.show()

# %% [markdown]
# ### <font color = 'blue'> Inference
# - It seems maximum matches were played in year 2013

# %%
df.age.value_counts()
# Out:
# 26    489
# 24    484
# 25    480
# 23    476
# 27    420
# 28    366
# 22    338
# 29    304
# 30    279
# 21    257
# 31    226
# 32    213
# 33    199
# 34    138
# 20    131
# 35    121
# 36    109
# 37     68
# 19     67
# 38     41
# 39     18
# 40     15
# 18     11
# 41      6
# 42      3
# 43      2
# 47      1
# Name: age, dtype: int64

# %% [markdown]
# #### Q3.What is the most common age of player and how many players of that age are present during 1999-2018 leagues data?

# %%
df['age'].value_counts().plot.bar()
plt.ylabel('count of age')
plt.show()

# %% [markdown]
# ### <font color = 'blue'> Inference
# - Appx 490 players are 26 years of old

# %%
sns.countplot(x = df['age'])
plt.show()

# %%
sns.countplot(x = df['position'])
plt.show()

# %% [markdown]
# ### <font color = 'blue'>  Inference
# - Players were only played at position of centre, right wing, left wing and deneseman. Less players were played at mixed positions

# %%
df['position'].count()
# Out:
# 5262

# %%
df['position'].value_counts()  # The total number of players in each position
# Out:
#  C         1462
#  D         1364
#  LW        1217
#  RW        1214
#  C/LW         2
#  LW/RW        1
#  LW/C         1
#  LW/D         1
# Name: position, dtype: int64

# %%
Positions = [1462,1364,1217,1214] 

my_labels = 'Center (C)','Defenseman (D)','Left-Wing (LW)','Right-Wing (RW)'

my_colors = ['forestgreen','darkorange','lightgray','dimgrey']

plt.pie(Positions, labels=my_labels, autopct='%1.1f%%', startangle=20, colors = my_colors, explode = (0.2, 0.05, 0.05, 0.05)) 
plt.title('Allotment of Positions') #assigned title of pie chart
plt.axis('equal') #scaling both axes equally for a perfectly round pie chart
plt.show() #displays the pie chart

# %% [markdown]
# ## <font color = 'green'> Bivariate Variables

# %% [markdown]
# #### There are three types of bivariate analysis :
#   - Bivariate Analysis between Categorical and Continuous features
#   - Bivariate Analysis between two Categorical features
#   - Bivariate Analysis between two Continuous features

# %% [markdown]
# ####  Different plots for bivariate analysis:
#    - i)	Box plot
#    - ii)	Scatter Plot
#    - iii)	Strip plot
#    - iv)	Voilin Plot
#    - v)	Swarm Plot
#    - vi)	Line Plot
#    - vii)	Cat Plot

# %% [markdown]
# ###  i)   Between Continuous feature and Continuous feature

# %% [markdown]
# #### Q1.  How is goals related to number of games played by different players ?

# %%
df.columns
# Out:
# Index(['season', 'player', 'age', 'team', 'position', 'games_played', 'goals',
#        'goals_per_game', 'assists', 'points', 'shots', 'shot_percentage',
#        'time_on_ice', 'blocks', 'hits'],
#       dtype='object')

# %%
df.nunique()
# Out:
# season               19
# player             2028
# age                  27
# team                 35
# position              8
# games_played         57
# goals                32
# goals_per_game      648
# assists              41
# points               61
# shots               182
# shot_percentage      32
# time_on_ice         854
# blocks              114
# hits                235
# dtype: int64

# %%
sns.lineplot(x = df['games_played'], y = df['goals'])
plt.show()

# %% [markdown]
# #### Q2. Players who played more than 60 games shows significantly higher goals i.e. 8 where as shows less goals if they played less than 30 games

# %%
df.head(3)
# Out:
#    season          player  age   team position  games_played  goals  \
# 0    2018    Pontus Aberg   24   TOT       LW             53      4
# 1    2018    Noel Acciari   26   BOS        C             60     10
# 2    2018  Michael Amadio   21   LAK        C             37      4
#
#    goals_per_game  assists  points  shots  shot_percentage  time_on_ice  \
# 0          0.0755       12      16     70              6.0        645.0
# 1          0.1667        1      11     66             15.0        775.0
# 2          0.1081        4       8     28             14.0        345.0
#
#    blocks  hits
# 0       8    24
# 1      41   152
# 2       9    18

# %%
sns.scatterplot(x = df['games_played'], y = df['hits'])
plt.show()

# %% [markdown]
# ###  <font color = 'blue'> Inference
# - Maximum number of hits were observed during the range of 70 to 80 games being played

# %% [markdown]
# ### Between Categorical feature and Continuous feature

# %%
df.head(3)
# Out:
#    season          player  age   team position  games_played  goals  \
# 0    2018    Pontus Aberg   24   TOT       LW             53      4
# 1    2018    Noel Acciari   26   BOS        C             60     10
# 2    2018  Michael Amadio   21   LAK        C             37      4
#
#    goals_per_game  assists  points  shots  shot_percentage  time_on_ice  \
# 0          0.0755       12      16     70              6.0        645.0
# 1          0.1667        1      11     66             15.0        775.0
# 2          0.1081        4       8     28             14.0        345.0
#
#    blocks  hits
# 0       8    24
# 1      41   152
# 2       9    18

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5262 entries, 0 to 5261
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   season           5262 non-null   int64
#  1   player           5262 non-null   object
#  2   age              5262 non-null   int64
#  3   team             5262 non-null   object
#  4   position         5262 non-null   object
#  5   games_played     5262 non-null   int64
#  6   goals            5262 non-null   int64
#  7   goals_per_game   5262 non-null   float64
#  8   assists          5262 non-null   int64
#  9   points           5262 non-null   int64
#  10  shots            5262 non-null   int64
#  11  shot_percentage  5262 non-null   float64
#  12  time_on_ice      5262 non-null   float64
#  13  blocks           5262 non-null   int64
#  14  hits             5262 non-null   int64
# dtypes: float64(3), int64(9), object(3)
# memory usage: 616.8+ KB

# %%
sns.boxplot(x = df['position'], y = df['points'])
plt.show()

# %% [markdown]
# ### <font color = 'blue'> Inference
#  - The median value for centre, left_wing and right_wing positions are almost same which is around 12 to 14 where as its less than 10 for defendman position

# %%
df['season'].value_counts()
# Out:
# 2013    492
# 2004    289
# 2001    282
# 2012    278
# 2000    276
# 2008    274
# 2006    273
# 2003    272
# 2009    268
# 2018    263
# 2015    263
# 2014    261
# 2002    260
# 2010    258
# 2017    257
# 2016    253
# 2011    251
# 2007    250
# 1999    242
# Name: season, dtype: int64

# %%
sns.boxplot(x = df['season'][df['season'].isin([2013, 2014, 2015, 2016, 2017, 2018])], y = df['goals'])
plt.show()

# %% [markdown]
# ### <font color = 'blue'> Inference
# - Median goals for all seasons between 2013 to 2018 are approximately 5
# - Also, we can see there are outliers in many features.

# %%
df.head(3)
# Out:
#    season          player  age   team position  games_played  goals  \
# 0    2018    Pontus Aberg   24   TOT       LW             53      4
# 1    2018    Noel Acciari   26   BOS        C             60     10
# 2    2018  Michael Amadio   21   LAK        C             37      4
#
#    goals_per_game  assists  points  shots  shot_percentage  time_on_ice  \
# 0          0.0755       12      16     70              6.0        645.0
# 1          0.1667        1      11     66             15.0        775.0
# 2          0.1081        4       8     28             14.0        345.0
#
#    blocks  hits
# 0       8    24
# 1      41   152
# 2       9    18

# %%
sns.barplot(x = df['player'].head(5), y = df['age'])
plt.show()

# %% [markdown]
# #### We can also check no of goals per game during certain period say 1999-2003

# %%
df.head(3)
# Out:
#    season          player  age   team position  games_played  goals  \
# 0    2018    Pontus Aberg   24   TOT       LW             53      4
# 1    2018    Noel Acciari   26   BOS        C             60     10
# 2    2018  Michael Amadio   21   LAK        C             37      4
#
#    goals_per_game  assists  points  shots  shot_percentage  time_on_ice  \
# 0          0.0755       12      16     70              6.0        645.0
# 1          0.1667        1      11     66             15.0        775.0
# 2          0.1081        4       8     28             14.0        345.0
#
#    blocks  hits
# 0       8    24
# 1      41   152
# 2       9    18

# %%
sns.violinplot(x = df['season'][df['season'].isin([1999, 2000, 2001, 2002, 2003])], y = df['goals_per_game'])
plt.show()

# %% [markdown]
# ### <font color = 'blue'> Inference
# - Median goals_per_game for all season between 1999 to 2003 are approximately 0.1

# %%
sns.swarmplot(x = df['season'][df['season'].isin([1999, 2000, 2001, 2002, 2003])], y = df['goals_per_game'])
plt.show()

# %% [markdown]
# ### ii)   Between two Categorical features

# %%
pd.crosstab(df['player'], df['position']).head(10)
# Out:
# position         C    C/LW    D    LW    LW/C    LW/D    LW/RW    RW
# player
# Aaron Downey      0       0    0     0       0       0        0     5
# Aaron Gavey       1       0    0     1       0       0        0     0
# Aaron Johnson     0       0    7     0       0       0        0     0
# Aaron Miller      0       0    2     0       0       0        0     0
# Aaron Palushaj    0       0    0     0       0       0        0     1
# Aaron Rome        0       0    4     0       0       0        0     0
# Aaron Volpatti    0       0    0     1       0       0        0     1
# Aaron Voros       0       0    0     3       0       0        0     0
# Aaron Ward        0       0    3     0       0       0        0     0
# Adam Burish       3       0    0     0       0       0        0     2

# %% [markdown]
# ### <font color = 'blue'> Inference
# - For example Aaron Gavey played centre as well as the left_wing positions

# %%
plt.figure(figsize = (15,10))
sns.stripplot(x = df['player'].head(10), y = df['position'])
plt.show()

# %% [markdown]
# ### <font color = 'blue'> Inference
#  - Players Noel Acciari and Michael Amadio played at the centre position

# %%
sns.catplot(x = df['position'], y = df['team'], jitter = False)
plt.show()

# %% [markdown]
# ### <font color = 'blue'> Inference
# - From all the teams there was no players who played at mixed positions

# %% [markdown]
# ### iii)   Multi Variate Analysis

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5262 entries, 0 to 5261
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   season           5262 non-null   int64
#  1   player           5262 non-null   object
#  2   age              5262 non-null   int64
#  3   team             5262 non-null   object
#  4   position         5262 non-null   object
#  5   games_played     5262 non-null   int64
#  6   goals            5262 non-null   int64
#  7   goals_per_game   5262 non-null   float64
#  8   assists          5262 non-null   int64
#  9   points           5262 non-null   int64
#  10  shots            5262 non-null   int64
#  11  shot_percentage  5262 non-null   float64
#  12  time_on_ice      5262 non-null   float64
#  13  blocks           5262 non-null   int64
#  14  hits             5262 non-null   int64
# dtypes: float64(3), int64(9), object(3)
# memory usage: 616.8+ KB

# %% [markdown]
# ##### Pair Plot

# %%
sns.pairplot(df,hue ='position', vars = ['goals','assists','shots','games_played','time_on_ice'], diag_kind = 'kde')
plt.show()

# %% [markdown]
# ### <font color = 'blue'> Inference
# - Goals, Assets and Shots features have right skewed distribution where as time_on_ice and games_played features have almost normal distribution
# - Also, Mixed positions are hardly played by any players

# %% [markdown]
# ##### Heat Map

# %% [markdown]
# - lets check the correlation among numerical variables using corr() function from pandas dataframe. Also we can use this corr() function values to plot map called Heatmap

# %%
corr = df.corr()
corr
# Out:
#                    season       age  games_played     goals  goals_per_game  \
# season           1.000000 -0.024527     -0.066537  0.033427        0.056054
# age             -0.024527  1.000000      0.100432 -0.024277       -0.049837
# games_played    -0.066537  0.100432      1.000000  0.361651        0.063900
# goals            0.033427 -0.024277      0.361651  1.000000        0.924798
# goals_per_game   0.056054 -0.049837      0.063900  0.924798        1.000000
# assists          0.013517  0.032985      0.313912  0.655635        0.592096
# points           0.024329  0.008871      0.367185  0.883623        0.808346
# shots            0.084963 -0.037326      0.507312  0.793164        0.669135
# shot_percentage -0.019449 -0.009285      0.145172  0.719150        0.745204
# time_on_ice      0.046921  0.095891      0.651323  0.493884        0.308434
# blocks           0.604037  0.042303      0.029159 -0.111499       -0.131078
# ...

# %%
plt.figure(figsize = (10,6))
sns.heatmap(corr, annot = True)
plt.show()

# %% [markdown]
# ###  <font color = 'blue'> Inference
# - Goals are highly correlated with goals_per_game, assets, points and shots
# - Blocks are highly correlated with hits and season
# - Here the dark color indicates less or negatively correlated and light color indicates positive correlated

# %% [markdown]
# #### Plotly

# %%
import plotly.express as px

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5262 entries, 0 to 5261
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   season           5262 non-null   int64
#  1   player           5262 non-null   object
#  2   age              5262 non-null   int64
#  3   team             5262 non-null   object
#  4   position         5262 non-null   object
#  5   games_played     5262 non-null   int64
#  6   goals            5262 non-null   int64
#  7   goals_per_game   5262 non-null   float64
#  8   assists          5262 non-null   int64
#  9   points           5262 non-null   int64
#  10  shots            5262 non-null   int64
#  11  shot_percentage  5262 non-null   float64
#  12  time_on_ice      5262 non-null   float64
#  13  blocks           5262 non-null   int64
#  14  hits             5262 non-null   int64
# dtypes: float64(3), int64(9), object(3)
# memory usage: 616.8+ KB

# %%
fig = px.scatter(x=df['team'], y=df['goals'], color=df['position'], animation_frame=df['season'])
fig.show()
# Out:
# <div>                            <div id="d0867c87-917b-423a-b31e-a11836651f5c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d0867c87-917b-423a-b31e-a11836651f5c")) {                    Plotly.newPlot(                        "d0867c87-917b-423a-b31e-a11836651f5c",                        [{"hovertemplate":"color= LW <br>animation_frame=2018<br>x=%{x}<br>y=%{y}<extra></extra>","legendgroup":" LW ","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":" LW ","orientation":"v","showlegend":true,"x":[" TOT "," LAK "," VAN "," VEG "," DET "," BOS "," SJS "," DET "," CHI "," COL "," FLA "," WSH "," EDM "," CBJ "," TOT "," MTL "," VEG "," TOT "," LAK "," TBL "," MTL "," MTL "," MTL "," CAR "," TOT "," DAL "," MIN "," VAN "," MIN "," MIN 
# ...

# %% [markdown]
# #### <font color='blue'> Inference
# - If we just drag cursor to any year, we can see how many goals that team scored in a perticular year(season) and also position of play.
#
# <font color='blue'> **For example:**
# - Team TOT scored 7 goals in 2016 with right_wing (RW) position.

# %%
fig = px.scatter(x=df['player'], y=df['goals'], color=df['position'], animation_frame=df['season'])
fig.show()
# Out:
# <div>                            <div id="36ba7fcf-6c4c-4235-a330-c72c014f29fc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("36ba7fcf-6c4c-4235-a330-c72c014f29fc")) {                    Plotly.newPlot(                        "36ba7fcf-6c4c-4235-a330-c72c014f29fc",                        [{"hovertemplate":"color= LW <br>animation_frame=2018<br>x=%{x}<br>y=%{y}<extra></extra>","legendgroup":" LW ","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":" LW ","orientation":"v","showlegend":true,"x":["Pontus Aberg","Andy Andreoff","Sven Baertschi","Pierre-Edouard Bellemare","Tyler Bertuzzi","Anders Bjork","Mikkel Boedker","David Booth","Lance Bouma","Gabriel Bourque","Connor Brickley","Andre Burakovsky","Drake Caggiula","Matt Calvert"
# ...

# %% [markdown]
# #### <font color='blue'>Inference
# - If we just drag cursor to any one year, we can see how many goals a player scored in a perticular year(season) and also his position of play.
#
# <font color='blue'>***For example***</font> : Matt Celvert scored 9 goals in 2018 when he played for left-wing (LW) position.
